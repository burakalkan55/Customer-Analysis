# %%
import numpy as np
import pandas as pd

# Specify the encoding
df = pd.read_csv('data.csv', encoding='latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.sample(5)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 235107    557625     22661   CHARLOTTE BAG DOLLY GIRL DESIGN        10
# 453708    575491     22086   PAPER CHAIN KIT 50'S CHRISTMAS          5
# 240912    558118     22358           KINGS CHOICE TEA CADDY          1
# 24379     538349     21286           RETROSPOT CANDLE  LARGE         1
# 307674    563924     22500  SET OF 2 TINS JARDIN DE PROVENCE         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 235107   6/21/2011 14:23       0.85     15159.0  United Kingdom
# 453708   11/9/2011 17:47       2.95     15531.0  United Kingdom
# 240912    6/27/2011 9:11       5.79         NaN  United Kingdom
# 24379   12/10/2010 14:59       5.06         NaN  United Kingdom
# 307674   8/21/2011 14:32       4.95     15984.0  United Kingdom
